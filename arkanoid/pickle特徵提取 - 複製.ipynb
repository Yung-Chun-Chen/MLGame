# %%
import pickle

for i in range(1, 19):
    file_path = "./log/ ("+  str(i) +").pickle"
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    print(data.keys())
# Out:
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])
# dict_keys(['record_format_version', 'ml'])

# %%
data['ml'].keys()
# Out:
# dict_keys(['scene_info', 'command'])

# %%
data['ml']['scene_info']
# Out:
# [{'frame': 0,
#   'status': 'GAME_ALIVE',
#   'ball': (93, 395),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 1,
#   'status': 'GAME_ALIVE',
#   'ball': (93, 395),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 2,
#   'status': 'GAME_ALIVE',
#   'ball': (86, 388),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 3,
#   'status': 'GAME_ALIVE',
#   'ball': (79, 381),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 4,
#   'status': 'GAME_ALIVE',
#   'ball': (72, 374),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 5,
#   'status': 'GAME_ALIVE',
#   'ball': (65, 367),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 6,
#   'status': 'GAME_ALIVE',
#   'ball': (58, 360),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 7,
#   'status': 'GAME_ALIVE',
#   'ball': (51, 353),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 8,
#   'status': 'GAME_ALIVE',
#   'ball': (44, 346),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 9,
#   'status': 'GAME_ALIVE',
#   'ball': (37, 339),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 10,
#   'status': 'GAME_ALIVE',
#   'ball': (30, 332),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 11,
#   'status': 'GAME_ALIVE',
#   'ball': (23, 325),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 12,
#   'status': 'GAME_ALIVE',
#   'ball': (16, 318),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 13,
#   'status': 'GAME_ALIVE',
#   'ball': (9, 311),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 14,
#   'status': 'GAME_ALIVE',
#   'ball': (2, 304),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 15,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 297),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 16,
#   'status': 'GAME_ALIVE',
#   'ball': (7, 290),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 17,
#   'status': 'GAME_ALIVE',
#   'ball': (14, 283),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 18,
#   'status': 'GAME_ALIVE',
#   'ball': (21, 276),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 19,
#   'status': 'GAME_ALIVE',
#   'ball': (28, 269),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 20,
#   'status': 'GAME_ALIVE',
#   'ball': (35, 262),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 21,
#   'status': 'GAME_ALIVE',
#   'ball': (42, 255),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 22,
#   'status': 'GAME_ALIVE',
#   'ball': (49, 248),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 23,
#   'status': 'GAME_ALIVE',
#   'ball': (56, 241),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 24,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 234),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 25,
#   'status': 'GAME_ALIVE',
#   'ball': (70, 227),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 26,
#   'status': 'GAME_ALIVE',
#   'ball': (77, 220),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 27,
#   'status': 'GAME_ALIVE',
#   'ball': (84, 213),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 28,
#   'status': 'GAME_ALIVE',
#   'ball': (91, 206),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 29,
#   'status': 'GAME_ALIVE',
#   'ball': (98, 199),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 30,
#   'status': 'GAME_ALIVE',
#   'ball': (105, 192),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 31,
#   'status': 'GAME_ALIVE',
#   'ball': (112, 185),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 32,
#   'status': 'GAME_ALIVE',
#   'ball': (119, 178),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 33,
#   'status': 'GAME_ALIVE',
#   'ball': (126, 171),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 34,
#   'status': 'GAME_ALIVE',
#   'ball': (133, 164),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 35,
#   'status': 'GAME_ALIVE',
#   'ball': (140, 157),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 36,
#   'status': 'GAME_ALIVE',
#   'ball': (147, 150),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 37,
#   'status': 'GAME_ALIVE',
#   'ball': (154, 143),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 38,
#   'status': 'GAME_ALIVE',
#   'ball': (161, 136),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 39,
#   'status': 'GAME_ALIVE',
#   'ball': (168, 129),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 40,
#   'status': 'GAME_ALIVE',
#   'ball': (175, 122),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 41,
#   'status': 'GAME_ALIVE',
#   'ball': (182, 115),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 42,
#   'status': 'GAME_ALIVE',
#   'ball': (189, 108),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 43,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 101),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 44,
#   'status': 'GAME_ALIVE',
#   'ball': (188, 94),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 45,
#   'status': 'GAME_ALIVE',
#   'ball': (181, 87),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 46,
#   'status': 'GAME_ALIVE',
#   'ball': (175, 80),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 47,
#   'status': 'GAME_ALIVE',
#   'ball': (182, 73),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 48,
#   'status': 'GAME_ALIVE',
#   'ball': (189, 66),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 49,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 59),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 50,
#   'status': 'GAME_ALIVE',
#   'ball': (188, 52),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 51,
#   'status': 'GAME_ALIVE',
#   'ball': (181, 45),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 52,
#   'status': 'GAME_ALIVE',
#   'ball': (174, 38),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 53,
#   'status': 'GAME_ALIVE',
#   'ball': (167, 31),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 54,
#   'status': 'GAME_ALIVE',
#   'ball': (160, 24),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 55,
#   'status': 'GAME_ALIVE',
#   'ball': (153, 17),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 56,
#   'status': 'GAME_ALIVE',
#   'ball': (146, 10),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 57,
#   'status': 'GAME_ALIVE',
#   'ball': (139, 3),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 58,
#   'status': 'GAME_ALIVE',
#   'ball': (132, 0),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 59,
#   'status': 'GAME_ALIVE',
#   'ball': (125, 7),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 60,
#   'status': 'GAME_ALIVE',
#   'ball': (118, 14),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 61,
#   'status': 'GAME_ALIVE',
#   'ball': (111, 21),
#   'platform': (80, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 62,
#   'status': 'GAME_ALIVE',
#   'ball': (104, 28),
#   'platform': (85, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 63,
#   'status': 'GAME_ALIVE',
#   'ball': (97, 35),
#   'platform': (90, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 64,
#   'status': 'GAME_ALIVE',
#   'ball': (90, 42),
#   'platform': (95, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 65,
#   'status': 'GAME_ALIVE',
#   'ball': (83, 45),
#   'platform': (100, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 66,
#   'status': 'GAME_ALIVE',
#   'ball': (76, 38),
#   'platform': (105, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 67,
#   'status': 'GAME_ALIVE',
#   'ball': (69, 31),
#   'platform': (110, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 68,
#   'status': 'GAME_ALIVE',
#   'ball': (62, 24),
#   'platform': (105, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 69,
#   'status': 'GAME_ALIVE',
#   'ball': (55, 17),
#   'platform': (100, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 70,
#   'status': 'GAME_ALIVE',
#   'ball': (48, 10),
#   'platform': (95, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 71,
#   'status': 'GAME_ALIVE',
#   'ball': (41, 3),
#   'platform': (90, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 72,
#   'status': 'GAME_ALIVE',
#   'ball': (34, 0),
#   'platform': (85, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 73,
#   'status': 'GAME_ALIVE',
#   'ball': (27, 7),
#   'platform': (80, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 74,
#   'status': 'GAME_ALIVE',
#   'ball': (20, 14),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 75,
#   'status': 'GAME_ALIVE',
#   'ball': (13, 21),
#   'platform': (70, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 76,
#   'status': 'GAME_ALIVE',
#   'ball': (6, 28),
#   'platform': (65, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 77,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 35),
#   'platform': (60, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 78,
#   'status': 'GAME_ALIVE',
#   'ball': (7, 42),
#   'platform': (55, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 79,
#   'status': 'GAME_ALIVE',
#   'ball': (14, 49),
#   'platform': (50, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 80,
#   'status': 'GAME_ALIVE',
#   'ball': (20, 55),
#   'platform': (45, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 81,
#   'status': 'GAME_ALIVE',
#   'ball': (13, 48),
#   'platform': (40, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 82,
#   'status': 'GAME_ALIVE',
#   'ball': (6, 41),
#   'platform': (35, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 83,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 34),
#   'platform': (40, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 84,
#   'status': 'GAME_ALIVE',
#   'ball': (7, 27),
#   'platform': (45, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 85,
#   'status': 'GAME_ALIVE',
#   'ball': (14, 20),
#   'platform': (50, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 86,
#   'status': 'GAME_ALIVE',
#   'ball': (21, 13),
#   'platform': (55, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 87,
#   'status': 'GAME_ALIVE',
#   'ball': (28, 6),
#   'platform': (60, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 88,
#   'status': 'GAME_ALIVE',
#   'ball': (35, 0),
#   'platform': (65, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 89,
#   'status': 'GAME_ALIVE',
#   'ball': (42, 7),
#   'platform': (70, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 90,
#   'status': 'GAME_ALIVE',
#   'ball': (49, 14),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 91,
#   'status': 'GAME_ALIVE',
#   'ball': (56, 21),
#   'platform': (70, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 92,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 28),
#   'platform': (65, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 93,
#   'status': 'GAME_ALIVE',
#   'ball': (70, 35),
#   'platform': (60, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 94,
#   'status': 'GAME_ALIVE',
#   'ball': (77, 42),
#   'platform': (55, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (60, 50),
#    (85, 50),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 95,
#   'status': 'GAME_ALIVE',
#   'ball': (84, 45),
#   'platform': (50, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 96,
#   'status': 'GAME_ALIVE',
#   'ball': (91, 38),
#   'platform': (45, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 97,
#   'status': 'GAME_ALIVE',
#   'ball': (98, 31),
#   'platform': (40, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 98,
#   'status': 'GAME_ALIVE',
#   'ball': (105, 24),
#   'platform': (45, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 99,
#   'status': 'GAME_ALIVE',
#   'ball': (112, 17),
#   'platform': (50, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  {'frame': 100,
#   'status': 'GAME_ALIVE',
#   'ball': (119, 10),
#   'platform': (55, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80),
#    (150, 80),
#    (25, 60)],
#   'hard_bricks': [(35, 50),
#    (110, 50),
#    (135, 50),
#    (150, 60),
#    (35, 70),
#    (135, 70),
# ...
#  {'frame': 913,
#   'status': 'GAME_ALIVE',
#   'ball': (95, 297),
#   'platform': (85, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 914,
#   'status': 'GAME_ALIVE',
#   'ball': (85, 290),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 915,
#   'status': 'GAME_ALIVE',
#   'ball': (75, 283),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 916,
#   'status': 'GAME_ALIVE',
#   'ball': (65, 276),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 917,
#   'status': 'GAME_ALIVE',
#   'ball': (55, 269),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 918,
#   'status': 'GAME_ALIVE',
#   'ball': (45, 262),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 919,
#   'status': 'GAME_ALIVE',
#   'ball': (35, 255),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 920,
#   'status': 'GAME_ALIVE',
#   'ball': (25, 248),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 921,
#   'status': 'GAME_ALIVE',
#   'ball': (15, 241),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 922,
#   'status': 'GAME_ALIVE',
#   'ball': (5, 234),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 923,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 227),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 924,
#   'status': 'GAME_ALIVE',
#   'ball': (10, 220),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 925,
#   'status': 'GAME_ALIVE',
#   'ball': (20, 213),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 926,
#   'status': 'GAME_ALIVE',
#   'ball': (30, 206),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 927,
#   'status': 'GAME_ALIVE',
#   'ball': (40, 199),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 928,
#   'status': 'GAME_ALIVE',
#   'ball': (50, 192),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 929,
#   'status': 'GAME_ALIVE',
#   'ball': (60, 185),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 930,
#   'status': 'GAME_ALIVE',
#   'ball': (70, 178),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 931,
#   'status': 'GAME_ALIVE',
#   'ball': (80, 171),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 932,
#   'status': 'GAME_ALIVE',
#   'ball': (90, 164),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 933,
#   'status': 'GAME_ALIVE',
#   'ball': (100, 157),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 934,
#   'status': 'GAME_ALIVE',
#   'ball': (110, 150),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 935,
#   'status': 'GAME_ALIVE',
#   'ball': (120, 143),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 936,
#   'status': 'GAME_ALIVE',
#   'ball': (130, 136),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 937,
#   'status': 'GAME_ALIVE',
#   'ball': (140, 129),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 938,
#   'status': 'GAME_ALIVE',
#   'ball': (150, 122),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 939,
#   'status': 'GAME_ALIVE',
#   'ball': (160, 115),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 940,
#   'status': 'GAME_ALIVE',
#   'ball': (170, 108),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 941,
#   'status': 'GAME_ALIVE',
#   'ball': (180, 101),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 942,
#   'status': 'GAME_ALIVE',
#   'ball': (190, 94),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 943,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 87),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 944,
#   'status': 'GAME_ALIVE',
#   'ball': (185, 80),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 945,
#   'status': 'GAME_ALIVE',
#   'ball': (175, 73),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 946,
#   'status': 'GAME_ALIVE',
#   'ball': (165, 66),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 947,
#   'status': 'GAME_ALIVE',
#   'ball': (155, 59),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 948,
#   'status': 'GAME_ALIVE',
#   'ball': (145, 52),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (110, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 949,
#   'status': 'GAME_ALIVE',
#   'ball': (135, 45),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 950,
#   'status': 'GAME_ALIVE',
#   'ball': (145, 38),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 951,
#   'status': 'GAME_ALIVE',
#   'ball': (155, 31),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 952,
#   'status': 'GAME_ALIVE',
#   'ball': (165, 24),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 953,
#   'status': 'GAME_ALIVE',
#   'ball': (175, 17),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 954,
#   'status': 'GAME_ALIVE',
#   'ball': (185, 10),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 955,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 3),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 956,
#   'status': 'GAME_ALIVE',
#   'ball': (185, 0),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 957,
#   'status': 'GAME_ALIVE',
#   'ball': (175, 7),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 958,
#   'status': 'GAME_ALIVE',
#   'ball': (165, 14),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 959,
#   'status': 'GAME_ALIVE',
#   'ball': (155, 21),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 960,
#   'status': 'GAME_ALIVE',
#   'ball': (145, 28),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 961,
#   'status': 'GAME_ALIVE',
#   'ball': (135, 35),
#   'platform': (85, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 962,
#   'status': 'GAME_ALIVE',
#   'ball': (125, 42),
#   'platform': (90, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 963,
#   'status': 'GAME_ALIVE',
#   'ball': (115, 49),
#   'platform': (95, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 964,
#   'status': 'GAME_ALIVE',
#   'ball': (105, 56),
#   'platform': (100, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 965,
#   'status': 'GAME_ALIVE',
#   'ball': (95, 63),
#   'platform': (105, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 966,
#   'status': 'GAME_ALIVE',
#   'ball': (85, 70),
#   'platform': (110, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 967,
#   'status': 'GAME_ALIVE',
#   'ball': (75, 77),
#   'platform': (115, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 968,
#   'status': 'GAME_ALIVE',
#   'ball': (65, 84),
#   'platform': (120, 400),
#   'bricks': [(125, 60), (25, 60), (60, 90)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80), (35, 90)]},
#  {'frame': 969,
#   'status': 'GAME_ALIVE',
#   'ball': (55, 85),
#   'platform': (125, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50), (35, 70), (25, 80)]},
#  {'frame': 970,
#   'status': 'GAME_ALIVE',
#   'ball': (45, 80),
#   'platform': (130, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 971,
#   'status': 'GAME_ALIVE',
#   'ball': (35, 87),
#   'platform': (125, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 972,
#   'status': 'GAME_ALIVE',
#   'ball': (25, 94),
#   'platform': (120, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 973,
#   'status': 'GAME_ALIVE',
#   'ball': (15, 101),
#   'platform': (115, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 974,
#   'status': 'GAME_ALIVE',
#   'ball': (5, 108),
#   'platform': (110, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 975,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 115),
#   'platform': (105, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 976,
#   'status': 'GAME_ALIVE',
#   'ball': (10, 122),
#   'platform': (100, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 977,
#   'status': 'GAME_ALIVE',
#   'ball': (20, 129),
#   'platform': (95, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 978,
#   'status': 'GAME_ALIVE',
#   'ball': (30, 136),
#   'platform': (90, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 979,
#   'status': 'GAME_ALIVE',
#   'ball': (40, 143),
#   'platform': (85, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 980,
#   'status': 'GAME_ALIVE',
#   'ball': (50, 150),
#   'platform': (80, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 981,
#   'status': 'GAME_ALIVE',
#   'ball': (60, 157),
#   'platform': (75, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 982,
#   'status': 'GAME_ALIVE',
#   'ball': (70, 164),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 983,
#   'status': 'GAME_ALIVE',
#   'ball': (80, 171),
#   'platform': (65, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 984,
#   'status': 'GAME_ALIVE',
#   'ball': (90, 178),
#   'platform': (60, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 985,
#   'status': 'GAME_ALIVE',
#   'ball': (100, 185),
#   'platform': (65, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 986,
#   'status': 'GAME_ALIVE',
#   'ball': (110, 192),
#   'platform': (70, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 987,
#   'status': 'GAME_ALIVE',
#   'ball': (120, 199),
#   'platform': (65, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 988,
#   'status': 'GAME_ALIVE',
#   'ball': (130, 206),
#   'platform': (60, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 989,
#   'status': 'GAME_ALIVE',
#   'ball': (140, 213),
#   'platform': (55, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 990,
#   'status': 'GAME_ALIVE',
#   'ball': (150, 220),
#   'platform': (50, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 991,
#   'status': 'GAME_ALIVE',
#   'ball': (160, 227),
#   'platform': (45, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 992,
#   'status': 'GAME_ALIVE',
#   'ball': (170, 234),
#   'platform': (40, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 993,
#   'status': 'GAME_ALIVE',
#   'ball': (180, 241),
#   'platform': (35, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 994,
#   'status': 'GAME_ALIVE',
#   'ball': (190, 248),
#   'platform': (30, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 995,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 255),
#   'platform': (35, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 996,
#   'status': 'GAME_ALIVE',
#   'ball': (185, 262),
#   'platform': (40, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 997,
#   'status': 'GAME_ALIVE',
#   'ball': (175, 269),
#   'platform': (40, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 998,
#   'status': 'GAME_ALIVE',
#   'ball': (165, 276),
#   'platform': (35, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  {'frame': 999,
#   'status': 'GAME_ALIVE',
#   'ball': (155, 283),
#   'platform': (30, 400),
#   'bricks': [(125, 60), (25, 60)],
#   'hard_bricks': [(35, 50)]},
#  ...]

# %%
data['ml']['command']
# Out:
# ['SERVE_TO_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  None,
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  ...]

# %%
data['ml']['scene_info'][0], data['ml']['command'][-0]
# Out:
# ({'frame': 0,
#   'status': 'GAME_ALIVE',
#   'ball': (93, 395),
#   'platform': (75, 400),
#   'bricks': [(50, 60),
#    (75, 60),
#    (100, 60),
#    (125, 60),
#    (60, 70),
#    (85, 70),
#    (110, 70),
#    (50, 80),
#    (75, 80),
#    (100, 80),
#    (125, 80)],
#   'hard_bricks': [(35, 50),
#    (60, 50),
#    (85, 50),
#    (110, 50),
#    (135, 50),
#    (25, 60),
#    (150, 60),
#    (35, 70),
#    (135, 70),
#    (25, 80),
#    (150, 80),
#    (35, 90),
#    (60, 90),
#    (85, 90),
#    (110, 90),
#    (135, 90)]},
#  'SERVE_TO_LEFT')

# %%
scene_info = data['ml']['scene_info']
command = data['ml']['command']

Ball_x = []
Ball_y = []
Ball_speed_x = []
Ball_speed_y = []
Direction = []
Platform = []
Command = []

for i, s in enumerate(scene_info[1:-2]):
    Ball_x.append(s['ball'][0])
    Ball_y.append(s['ball'][1])
    Platform.append(s['platform'][0])
    Ball_speed_x.append(scene_info[i+2]["ball"][0] - scene_info[i+1]["ball"][0])
    Ball_speed_y.append(scene_info[i+2]["ball"][1] - scene_info[i+1]["ball"][1])
    if Ball_speed_x[-1] > 0:
        if Ball_speed_y[-1] > 0:
            # 右下
            Direction.append(0)
        else:
            # 右上
            Direction.append(1)
    else:
        if Ball_speed_y[-1] > 0:
            # 左下
            Direction.append(2)
        else:
            # 左上
            Direction.append(3)
            
for c in command[1:-2]:
    if c == "NONE":
        Command.append(0)
    elif c == "MOVE_LEFT":
        Command.append(-1)
    elif c == "MOVE_RIGHT":
        Command.append(1)

# %%
import numpy as np

numpy_data = np.array([Ball_y, Ball_speed_x, Ball_speed_y, Direction, Platform])
X = np.transpose(numpy_data) 
y = command

# %%
X, y
# Out:
# (array([[395,  -7,  -7,   3,  75],
#         [388,  -7,  -7,   3,  75],
#         [381,  -7,  -7,   3,  75],
#         ...,
#         [ 28,  10,   7,   0,  70],
#         [ 35,  10,   7,   0,  65],
#         [ 42,  10,   7,   0,  60]]),
#  ['SERVE_TO_LEFT',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   None,
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'NONE',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_RIGHT',
#   'MOVE_RIGHT',
#   'NONE',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   'MOVE_LEFT',
#   ...])

# %%
# 提取特徵
import numpy as np

scene_info = data['ml']['scene_info']
command = data['ml']['command']

k = range(1, len(scene_info)-1)

#ball_x = np.array([scene_info[i]['ball'][0] for i in k])
ball_y = np.array([scene_info[i]['ball'][1] for i in k])
ball_speed_x = np.array([scene_info[i+1]['ball'][0] - scene_info[i]['ball'][0] for i in k])
ball_speed_y = np.array([scene_info[i+1]['ball'][1] - scene_info[i]['ball'][1] for i in k])
direction = np.where(np.vstack((ball_speed_x, ball_speed_y)) > 0, [[1],[0]], [[2],[3]]).sum(axis=0)  # x y: ++1, +-4, -+2, --3
platform = np.array([scene_info[i]['platform'][0] for i in k])
target = np.where(np.array(command) == 'NONE', 0,
                  np.where(np.array(command) == 'MOVE_LEFT', -1, 1))[1:-1]  # [0] SERVE_TO_RIGHT, [1897] None

# %%
# 也可以使用 pandas
X = np.hstack((#ball_x.reshape(-1, 1),
               ball_y.reshape(-1, 1),
               ball_speed_x.reshape(-1, 1),
               ball_speed_y.reshape(-1, 1),
               direction.reshape(-1, 1),
               platform.reshape(-1, 1)))
y = target

# %%
X, y
# Out:
# (array([[395,  -7,  -7,   5,  75],
#         [388,  -7,  -7,   5,  75],
#         [381,  -7,  -7,   5,  75],
#         ...,
#         [ 35,  10,   7,   1,  65],
#         [ 42,  10,   7,   1,  60],
#         [ 49,  10,   6,   1,  55]]),
#  array([ 0,  0,  0, ..., -1, -1,  1]))

# %%
# train data
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=1)
print(model.fit(X, y))
print(model.score(X, y))
# Out:
# KNeighborsClassifier(n_neighbors=1)
# 0.9636493228795439

# %%
with open('my_model.pickle', 'wb') as f:
    pickle.dump(model, f)
